# %%
import numpy as np
import pandas as pd
from bokeh.charts import Bar, output_file, show
from bokeh.io import output_notebook

from thumos14_helper import Thumos14

output_notebook()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %%
th_ds = Thumos14('../data/thumos14/')
seg_info = {'val': th_ds.segments_info(),
            'test': th_ds.segments_info('test')}

# %%
n_frames, uniq_frames, counts = {}, {}, {}
for i in seg_info:
    n_frames[i] = seg_info[i].loc[:, 'n-frames']
    uniq_frames[i], counts[i] = np.unique(n_frames[i], return_counts=True)

# Visualization
# TODO: Include tab for test
df = pd.DataFrame({'Unique Frames': uniq_frames['val'],
                   'Counts': counts['val']})
p = Bar(df, 'Unique Frames', values='Counts', title="Frames Distrib")
f = show(p)
# Out:
#     <div class="plotdiv" id="e53c7e1f-3224-4360-94ff-6aae7ac4763b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e53c7e1f-3224-4360-94ff-6aae7ac4763b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e53c7e1f-3224-4360-94ff-6aae7ac4763b' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"527ae105-59e9-4e24-9f33-eb08484ac257": {"version": "0.11.0", "roots": {"root_ids": ["3507c6d5-1a00-45d9-8316-576b3e682024"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "42532045-eea6-4417-8d9b-5190444b2929"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "ea508ef7-5cac-49b6-adbb-6b862239d6cf"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "156dabfc-2e47-4f9d-9de3-d02323db1ffd"}}, "type": "GlyphRenderer", "id": "870c1d6d-d203-476a-b779-551fc63f21cb"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "1184a83f-84cb-43f8-a9f9-b56c31fad694"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "a3bdb186-724a-439b-bfc0-2ab74522b8d1"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "f27babd2-82a7-4909-ac37-8128540fb4a0"}}, "type": "GlyphRenderer", "id": "98bb4b24-9cc4-402f-89a0-05bf00f08eee"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "19927377-f6ce-4152-b09e-186eb7b37e57"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"Unique Frames": 553.0}], "width": [0.8], "Unique Frames": [553.0], "fill_alpha": [0.8], "height": [1.0], "color": ["#f22c40"], "y": [0.5], "x": ["553.0"]}}, "type": "ColumnDataSource", "id": "b9f01cc0-ceac-4ffe-a41b-99be624f8ca8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "e3881586-c821-4315-9b63-b96e078f8b2b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "91d8ec32-49fd-4d24-b2b1-192092b58520"}}, "type": "GlyphRenderer", "id": "50c6122e-5e5a-4428-938c-8782c7a4aef0"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"Unique Frames": 2716.0}], "width": [0.8], "Unique Frames": [2716.0], "fill_alpha": [0.8], "height": [1.0], "color": ["#f22c40"], "y": [0.5], "x": ["2716.0"]}}, "type": "ColumnDataSource", "id": "599b98eb-6462-4fe2-a4c1-caaac7214776"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "0848cc12-a228-415d-b9e6-754538a3feaf"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "8d05587c-8e8e-4cc1-8cc3-e5205a663d15"}}, "type": "GlyphRenderer", "id": "0ac27be3-dfad-4754-8e94-685a7d3000fe"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"Unique Frames": 136.0}], "width": [0.8], "Unique Frames": [136.0], "fill_alpha": [0.8], "height": [35.0], "color": ["#f22c40"], "y": [17.5], "x": ["136.0"]}}, "type": "ColumnDataSource", "id": "386da385-02d0-43ad-ba86-f62d8af2b429"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"},  ...

# %% [markdown]
# Proposal are designed to achieve high-recall so we should analyze the *"CFD"* of the number of frames in order to fix our temporal length.
#
# *Note: A multi-scale approach is an interesting future direction but it might be conditioned by current benchmarks.*

# %%
cum_counts = {}
for i in seg_info:
    cum_counts[i] = np.cumsum(counts[i]) / 1.0 / counts[i].sum()

# Visualization
# TODO: Include tab for test
df = pd.DataFrame({'Unique Frames': uniq_frames['val'],
                   'Counts': cum_counts['val']})
p = Bar(df, 'Unique Frames', values='Counts', title="Cumulative Distrib")
f = show(p)

for i in seg_info:
    print '----{}----'.format(i)
    for j in [0.5, 0.75, 0.9, 0.95, 0.99]:
        v = uniq_frames[i][cum_counts[i] >= j].min() 
        print '{} videos less than {} frames'.format(j, v)
# Out:
#     <div class="plotdiv" id="27120ccb-025f-4ba4-a2db-0f4db188e2ab"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27120ccb-025f-4ba4-a2db-0f4db188e2ab");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27120ccb-025f-4ba4-a2db-0f4db188e2ab' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"53c51bae-93da-46fc-bdaa-1802c2458f7e": {"version": "0.11.0", "roots": {"root_ids": ["3507c6d5-1a00-45d9-8316-576b3e682024", "981fbcdb-f6a4-4c46-8a47-94d188299498"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "e793f2d7-e78c-48ac-8cba-66287ca978a0"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"Unique Frames": 202.0}], "width": [0.8], "Unique Frames": [202.0], "fill_alpha": [0.8], "height": [0.8446382428940569], "color": ["#f22c40"], "y": [0.42231912144702843], "x": ["202.0"]}}, "type": "ColumnDataSource", "id": "7911c23a-bd10-439c-9732-056dd23e07de"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "4a02ed31-d28c-456e-88a8-5b02b832ec15"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "4000cc45-a594-40e1-ba69-573a97bf70cb"}}, "type": "GlyphRenderer", "id": "ab5808df-50cd-45e3-8bbb-4ab7954285d8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "8686f170-3d01-4fe1-801c-e1f9e784c078"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "27d8696a-1113-429a-b863-e516155804ef"}}, "type": "GlyphRenderer", "id": "5039396b-731f-4bb5-a2e7-f2ac5d3d0109"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "def8e7f1-a007-4c82-8098-bf931c498d05"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "1184a83f-84cb-43f8-a9f9-b56c31fad694"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "27d8696a-1113-429a-b863-e516155804ef"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"Unique Frames": 136.0}], "width": [0.8], "Unique Frames": [136.0], "fill_alpha": [0.8], "height": [35.0], "color": ["#f22c40"], "y": [17.5], "x": ["136.0"]}}, "type": "ColumnDataSource", "id": "386da385-02d0-43ad-ba86-f62d8af2b429"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "6b32b1c3-709e-4d36-b362-4e69fca1e551"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "53e005fd-f174-4b0e-b6eb-4e7b8d40b267"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "3507c6d5-1a00-45d9-8316-576b3e682024"}, "axis_label": "Sum( Counts )", "formatter": {"type": "BasicTickFormatter", "id": "5e3a77b9-8bf4-41d2-be33-f5e3fce9ae7f"}, "ticker": {"type": "BasicTicker ...
# ----test----
# 0.5 videos less than 97.0 frames
# 0.75 videos less than 181.0 frames
# 0.9 videos less than 264.0 frames
# 0.95 videos less than 337.0 frames
# 0.99 videos less than 586.0 frames
# ----val----
# 0.5 videos less than 88.0 frames
# 0.75 videos less than 163.0 frames
# 0.9 videos less than 235.0 frames
# 0.95 videos less than 286.0 frames
# 0.99 videos less than 514.0 frames

# %% [markdown]
# For an IOU of 0.5 we can choose a window size equal to the half of the previous number frames. For a single scale multi-segment approach and seeking a model with high-recall, we should choose a canonical size around 143 - 169 frames.
#
# Notes:
# 1. A multi-scale approach can improve correct retrieval of small segments.
# 2. It's highly possible that this criteria generate an unbalanced distribution given the distribution of the data.
